# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Desktop\\program'

# %%
os.chdir("C:\\Users\\Admin\\Desktop\\program")

# %% [markdown]
#  # 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top5 and bottom 5 records.

# %%
data=pd.read_csv('youtube_dislike_dataset.csv')
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
data.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
data.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# # 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
data.shape
# Out:
# (37422, 12)

# %% [markdown]
#  # Inference :
#
#    * view_count,likes,dislikes,comment_count are integer Data type
#    * video_id,title,channel_id,channel_title,published_at,tags,description,comments are object Data type of total 12 columns
#    * The datset having the shape of 37422 rows and 12 columns (37422, 12)
#    * those data about youtube video

# %% [markdown]
# # 3. Check for the Percentage of the missing values and drop or impute them.

# %%
data.isnull()
# Out:
#        video_id  title  channel_id  channel_title  published_at  view_count  \
# 0         False  False       False          False         False       False
# 1         False  False       False          False         False       False
# 2         False  False       False          False         False       False
# 3         False  False       False          False         False       False
# 4         False  False       False          False         False       False
# ...         ...    ...         ...            ...           ...         ...
# 37417     False  False       False          False         False       False
# 37418     False  False       False          False         False       False
# 37419     False  False       False          False         False       False
# 37420     False  False       False          False         False       False
# 37421     False  False       False          False         False       False
#
# ...

# %%
data.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
data.isnull().mean()*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
data.drop(columns=['comments'], inplace=True)

# %% [markdown]
# # 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
data.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
data.describe(include='object')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# # 5. Convert datatype of column published_at from object to pandas datetime.

# %%
data["published_at"]=pd.to_datetime(data["published_at"])
data["published_at"]
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  datetime64[ns]
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# ### published_at column datatype were changed

# %% [markdown]
# # 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
data['published_month'] = data['published_at'].dt.month
data['published_month']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37422, dtype: int64

# %% [markdown]
# # 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

# %%
month_Names = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
               7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
# data['published_month'] = data['published_month'].map(month_Names)
# data['published_month']

# %%
month_names = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
               7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
#data['published_month'] = data['published_month'].replace(month_names,inplace=True)
#data['published_month']

# %%
data['published_month'] = data['published_at'].dt.strftime('%B')
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
monthly_video_published = data.groupby('published_month')['video_id'].count().sort_values(ascending=False)
monthly_video_published
# Out:
# published_month
# October      4991
# September    4880
# November     4851
# August       4262
# December     3072
# July         2340
# June         2316
# March        2258
# February     2137
# April        2126
# January      2108
# May          2081
# Name: video_id, dtype: int64

# %% [markdown]
# # 9. Find the count of unique video_id, channel_id and channel_title.

# %%
video_id_count = data['video_id'].nunique()
video_id_count
# Out:
# 37264

# %%
channel_id_count = data['channel_id'].nunique()
channel_id_count
# Out:
# 10891

# %%
channel_title_count = data['channel_title'].nunique()
channel_title_count
# Out:
# 10813

# %%
print("The Unique video_id_ count is",video_id_count) 

print("The Unique channel_id count is",channel_id_count)

print("The Unique channel_title count is",channel_title_count)
# Out:
# The Unique video_id_ count is 37264
# The Unique channel_id count is 10891
# The Unique channel_title count is 10813

# %% [markdown]
# # 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
top_10_channels = data['channel_title'].value_counts().head(10)
top_10_channels
# Out:
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: channel_title, dtype: int64

# %%
bottom_10_channels = data['channel_title'].value_counts().tail(10)
bottom_10_channels
# Out:
# Ohio State Football          1
# boqer123                     1
# xisumatwo                    1
# Gaming with Griff Griffin    1
# KoncreteJungle               1
# JFlaMusic                    1
# Ron Bielecki                 1
# GLAD Empire                  1
# Hip Hop News Uncensored      1
# Master Podcast               1
# Name: channel_title, dtype: int64

# %% [markdown]
# # 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
likes_title=pd.pivot_table(data,index="channel_title",values="likes")
likes_title
# Out:
#                              likes
# channel_title
#    SilverName         1.327000e+03
#    [KIMDUMB]          9.798000e+03
#   (Inter TV channel)  1.688000e+03
#   -    IT!            2.411900e+04
#   - MBN               1.857300e+04
# ...                            ...
# zanny                 8.060080e+04
# zayn                  2.117410e+05
# zefrank1              1.361673e+05
# zollotech             1.446720e+04
# zoom                  1.154281e+06
#
# [10813 rows x 1 columns]

# %%
likes_title.max()
# Out:
# likes    7063866.5
# dtype: float64

# %% [markdown]
# # OR

# %%
maximum_likes = data["likes"].max()
maximum_likes_title = data[data["likes"] == maximum_likes]['title'].values[0]
print("maximum_likes_title  :",maximum_likes_title)
# Out:
# maximum_likes_title  : BTS () 'Dynamite' Official MV

# %%
minimum_likes = data["likes"].min()
minimum_likes_title = data[data["likes"] == minimum_likes]["title"].values[0]
print("minimum_likes_title  :",minimum_likes_title)
# Out:
# minimum_likes_title  : Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %%
# 
    * the title of the video which has the maximum number of likes : BTS () 'Dynamite' Official MV
    * the title of the video havingminimum likes   : Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# # 12. Find the title of the video which has the maximum number of dislikes and the title of the video havingminimum dislikes and write your inferences.

# %%
maximum_dislikes = data["dislikes"].max()
maximum_dislikes_title = data[data["dislikes"] == maximum_dislikes]['title'].values[0]
print("maximum_dislikes_title  :",maximum_dislikes_title)
# Out:
# maximum_dislikes_title  : Cuties | Official Trailer | Netflix

# %%
minimum_dislikes = data["dislikes"].min()
minimum_dislikes_title = data[data["dislikes"] == minimum_dislikes]["title"].values[0]
print("maximum_dislikes_title  :",minimum_dislikes_title)
# Out:
# maximum_dislikes_title  : Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %%
# inference:
  
    * the title of the video which has the maximum number of dislikes : Cuties | Official Trailer | Netflix
    * the title of the video having minimum dislikes : Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
#  # 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
correlation_value = data['view_count'].corr(data['dislikes'])
correlation_value
# Out:
# 0.6845758297072607

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.corr()
# Out:
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.784199  0.684576       0.464442
# likes            0.784199  1.000000  0.679668       0.581117
# dislikes         0.684576  0.679668  1.000000       0.391999
# comment_count    0.464442  0.581117  0.391999       1.000000

# %%
#  
   * Correlation of Dislikes and View_count value : 0.6845758297072607
   * It was the maximum value in correlation Table
   * Finally, it affect the view by people disliking the video

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.scatter(data['dislikes'],data['view_count'],c='red',alpha =1)
plt.xlabel('dislikes')
plt.ylabel('view_count')
plt.title('The number of views have effect on people disliked the video')

plt.show()

# %% [markdown]
# # 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
january_videos = data[data['published_month'] == 'january']
print(january_videos)
count_january_videos = len(january_videos)
print(f"Count of videos published in January: {count_january_videos}")
# Out:
# Empty DataFrame
# Columns: [video_id, title, channel_id, channel_title, published_at, view_count, likes, dislikes, comment_count, tags, description, published_month]
# Index: []
# Count of videos published in January: 0

# %%
january_videos = data[data['published_month'] == 'January']
january_videos

print("Display all the information about the videos that were published in January :")
january_videos.describe()

print("the count of videos that were published in January:")
january_videos.count()
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %% [markdown]
# # the count of videos that were published in January : 2108

# %% [markdown]
#                                                                             # Mukesh Kanna M K
